# %% [markdown]
# <a href="https://colab.research.google.com/github/VitorKF/PCD-Aula03-Git-e-Github-no-colab/blob/main/Exerc%C3%ADcio_usando_GitHub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git --version
# !git config --global user.name VitorKF
# !git config --global user.email vkopacekfernandes@gmail.com
# !git config --global init.defaultBranch main
# !git config --global --list
# Out:
# git version 2.34.1
# user.name=VitorKF
# user.email=vkopacekfernandes@gmail.com
# init.defaultbranch=main

# %%
nome = str (input("Informe o nome do aluno: "))
a = float (input("Informe a primeira nota do aluno " + nome + ": "))
b = float (input("Informe a segunda nota do aluno " + nome + ": "))
c = float (input("Informe a terceira nota do aluno " + nome + ": "))

media = (a + b + c) / 3

print(f'As notas do aluno {nome} são {a}, {b} e {c}')
print(f'A media dos das notas de {nome} é {media}')
# Out:
# Informe o nome do aluno: A
# Informe a primeira nota do aluno A: 10
# Informe a segunda nota do aluno A: 20
# Informe a terceira nota do aluno A: 30
# As notas do aluno A são 10.0, 20.0 e 30.0
# A media dos das notas de A é 20.0

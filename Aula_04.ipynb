# %% [markdown]
# <a href="https://colab.research.google.com/github/VitorKF/Aulas-Programacao-para-Ciencia-de-Dados/blob/main/Aula_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git --version
# !git config --global user.name VitorKF
# !git config --global user.email vkopacekfernandes@gmail.com
# !git config --global init.defaultBranch main
# !git config --global --list
# Out:
# git version 2.34.1
# user.name=VitorKF
# user.email=vkopacekfernandes@gmail.com
# init.defaultbranch=main

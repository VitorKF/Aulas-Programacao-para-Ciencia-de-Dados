# %% [markdown]
# <a href="https://colab.research.google.com/github/VitorKF/PCD-Aula03-Git-e-Github-no-colab/blob/main/PCD_Git_e_Github_no_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git --version
# !git config --global user.name VitorKF
# !git config --global user.email vkopacekfernandes@gmail.com
# !git config --global init.defaultBranch main
# !git config --global --list
# Out:
# git version 2.34.1
# user.name=VitorKF
# user.email=vkopacekfernandes@gmail.com
# init.defaultbranch=main

# %%
# !git clone https://github.com/VitorKF/PCD-Aula03-Git-e-Github-no-colab.git
# Out:
# Cloning into 'PCD-Aula03-Git-e-Github-no-colab'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# %cd PCD-Aula03-Git-e-Github-no-colab
# !ls
# !git status
# !git remote -v
# Out:
# /content/PCD-Aula03-Git-e-Github-no-colab
# README.md
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# origin	https://github.com/VitorKF/PCD-Aula03-Git-e-Github-no-colab.git (fetch)
# origin	https://github.com/VitorKF/PCD-Aula03-Git-e-Github-no-colab.git (push)

# %%
# %%writefile README.md
# # PCD - Aula 03
#
# Arquivos da Aula 03: Colab, Github e Git.
#
# ## Autor
# Seu Nome

# %%
# !cat README.md
# Out:
# # PCD - Aula 03
#
# Arquivos da Aula 03: Colab, Github e Git.
#
# ## Autor
# Seu Nome

# %%
# !git add README.md

# %%
# !git commit -m "UPdate class README"
# Out:
# [main d7bf946] UPdate class README
#  1 file changed, 6 insertions(+), 1 deletion(-)

# %%
# !git push origin main
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 326 bytes | 326.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/VitorKF/PCD-Aula03-Git-e-Github-no-colab.git
#    9b21aac..d7bf946  main -> main

# %%
# !apt-get -qq update
# !apt-get -qq install gh
# !GH_PROMPT_DISABLED=1 gh auth login --hostname github.com --git-protocol https --web
# !gh auth setup-git
# !gh auth status
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
#
# ! First copy your one-time code: 7169-F28D
# Open this URL to continue in your web browser: https://github.com/login/device
# ✓ Authentication complete.
# - gh config set -h github.com git_protocol https
# ✓ Configured git protocol
# ! Authentication credentials saved in plain text
# ✓ Logged in as VitorKF
# github.com
#   ✓ Logged in to github.com account VitorKF (/root/.config/gh/hosts.yml)
#   - Active account: true
#   - Git operations protocol: https
#   - Token: gho_************************************
#   - Token scopes: 'gist', 'read:org', 'repo'

# %%
# !git pull origin main
# Out:
# From https://github.com/VitorKF/PCD-Aula03-Git-e-Github-no-colab
#  * branch            main       -> FETCH_HEAD
# Already up to date.
